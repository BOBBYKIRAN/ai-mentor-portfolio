# %% [markdown]
# <a href="https://colab.research.google.com/github/BOBBYKIRAN/ai-mentor-portfolio/blob/main/Day10_MultiAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q "numpy<2.0"

# %%
# !pip install -q --upgrade crewai litellm google-generativeai google-genai

# %%
import os, getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("Enter Gemini API Key: ")

print("API key set")
# Out:
# Enter Gemini API Key: ··········
# API key set

# %%
from crewai import Agent, Task, Crew, Process

print("CrewAI imported successfully")
# Out:
# 06:34:04 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 06:34:04 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# CrewAI imported successfully

# %%
llm = "gemini/gemini-2.5-flash"

print(llm)
# Out:
# gemini/gemini-2.5-flash

# %%
researcher = Agent(
    role="Placement Researcher",
    goal="Compile concise, factual placement-prep notes for B.Tech students",
    backstory="You are a research analyst who prepares short factual placement briefs in bullet form.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Researcher agent created")
# Out:
# Researcher agent created

# %%
writer = Agent(
    role="Placement Brief Writer",
    goal="Convert research notes into a clean 1-page placement brief in markdown",
    backstory="You write clear student-friendly placement briefs with headings and actionable takeaways.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Writer agent created")
# Out:
# Writer agent created

# %%
research_task = Task(
    description=(
        "Research TCS Digital placement preparation for B.Tech students. "
        "Include hiring process, technical stack, eligibility, recent hiring trends, "
        "and preparation tips. Give 3-5 bullets per section."
    ),
    agent=researcher,
    expected_output=(
        "Markdown bullet list with 5 sections: Hiring Process, Technical Stack, "
        "Eligibility, Recent Hiring Trends, Prep Tips."
    ),
)

print("Research task created")
# Out:
# Research task created

# %%
write_task = Task(
    description=(
        "Using the research notes, produce a 1-page placement brief for B.Tech students. "
        "Use markdown format. Include a 3-line opening hook, 5 clear sections, "
        "and a 3-line closing call-to-action."
    ),
    agent=writer,
    expected_output='1-page markdown brief titled "TCS Digital — Placement Prep Brief".',
)

print("Writer task created")
# Out:
# Writer task created

# %%
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    process=Process.sequential,
    verbose=True,
)

print("Crew created successfully")
# Out:
# Crew created successfully

# %%
result = await crew.kickoff_async()

print("\n\n=== FINAL OUTPUT ===\n")
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 84d8a69c-896d-4631-849b-bd1805d3a476                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  ID: fbe9c258-9751-45d7-ae2d-cfc7090c59ba                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **TCS Digital Placement Preparation for B.Tech Students**                                                      │
# │                                                                                                                 │
# │  ### Hiring Process                                                                                             │
# │  *   **Online Assessment:** Typically includes advanced aptitude, reasoning, and two to three coding questions  │
# │  (often with higher difficulty than TCS Ninja).                                                                 │
# │  *   **Technical Interview (TI):** Focuses heavily on Data Structures & Algorithms, programming concepts,       │
# │  project discussions, and core computer science fundamentals.                                                   │
# │  *   **Managerial Interview (MI):** May assess problem-solving approach, teamwork, leadership potential, and    │
# │  ability to handle complex scenarios.                                                                           │
# │  *   **HR Interview (HRI):** Covers communication skills, career aspirations, fit for company culture, and      │
# │  background verification.                                                                                       │
# │                                                                                                                 │
# │  ### Technical Stack                                                                                            │
# │  *   **Core Programming Languages:** Strong proficiency in at least one language like Java, Python, C++, or C#  │
# │  is essential.                                                                                                  │
# │  *   **Data Structures & Algorithms (DSA):** In-depth understanding and implementation skills for various DSA   │
# │  are critical for coding rounds and technical interviews.                                                       │
# │  *   **Databases:** Knowledge of SQL (queries, normalization, ACID properties) and basic understanding of       │
# │  NoSQL databases.                                                                                               │
# │  *   **Cloud Computing Fundamentals:** Familiarity with concepts of cloud platforms (AWS, Azure, GCP) and       │
# │  services is highly valued.                                                                                     │
# │  *   **Emerging Technologies:** Basic understanding of AI/ML, IoT, Blockchain, or Big Data concepts can be a    │
# │  differentiator.                                                                                                │
# │                                                                                                                 │
# │  ### Eligibility                                                                                                │
# │  *   **Academic Scores:** Consistent academic performance, generally 60% or 6.0 CGPA throughout 10th, 12th,     │
# │  and B.Tech/BE.                                                                                                 │
# │  *   **Degree and Branches:** B.Tech/BE in Computer Science, Information Technology, Electronics &              │
# │  Communication, Electrical & Electronics, and related disciplines.                                              │
# │  *   **Year of Passing:** Typically targeted towards final-year students (e.g., 2024 batch) or recent           │
# │  graduates within a specific window.                                                                            │
# │  *   **Backlogs:** No active backlogs allowed at the time of application or joining; candidates must have       │
# │  cleared all subjects.                                                                                          │
# │  *   **Education Gap:** A maximum of 1-2 years gap in education is usually permissible, with valid              │
# │  justification.                                                                                                 │
# │                                                                                                                 │
# │  ### Recent Hiring Trends                                                                                       │
# │  *   **Increased Coding Difficulty:** The coding section in the online assessment often includes medium to      │
# │  hard-level problems requiring optimal solutions.                                                               │
# │  *   **Focus on Problem-Solving:** Greater emphasis on a candidate's approach to problem-solving rather than    │
# │  just memorized solutions.                                                                                      │
# │  *   **Cloud & Emerging Tech Relevance:** Growing preference for candidates demonstrating foundational          │
# │  knowledge or projects related to cloud computing or other emerging technologies.                               │
# │  *   **Adaptive Testing:** Online assessments sometimes utilize adaptive testing, where question difficulty     │
# │  adjusts based on previous answers.                                                                             │
# │  *   **Full-Stack/Specialized Skills:** Demand for candidates with either full-stack development skills or      │
# │  deep expertise in a specific area like AI/ML engineering.                                                      │
# │                                                                                                                 │
# │  ### Prep Tips                                                                                                  │
# │  *   **Master DSA:** Practice Data Structures and Algorithms extensively on platforms like LeetCode,            │
# │  HackerRank, or GeeksforGeeks, focusing on all difficulty levels.                                               │
# │  *   **Strong Language Fundamentals:** Build a solid foundation in your chosen programming language, including  │
# │  OOP concepts, multi-threading, and error handling.                                                             │
# │  *   **Build Projects:** Develop 2-3 significant projects, preferably using relevant technologies (e.g., web    │
# │  development, ML, cloud services), and be prepared to discuss them in detail.                                   │
# │  *   **Core CS Subjects:** Revise fundamentals of Operating Systems, Database Management Systems, and Computer  │
# │  Networks.                                                                                                      │
# │  *   **Mock Interviews:** Participate in mock technical and HR interviews to refine your communication skills   │
# │  and ability to articulate solutions and experiences clearly.                                                   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  ID: 18d49bc2-2556-4ec5-b2ad-1a60a9ff874c                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # TCS Digital — Placement Prep Brief                                                                           │
# │                                                                                                                 │
# │  Ready to accelerate your career with a premium role at TCS?                                                    │
# │  TCS Digital offers B.Tech graduates an opportunity to work on cutting-edge technologies and innovative         │
# │  projects.                                                                                                      │
# │  This brief outlines everything you need to know to secure your spot.                                           │
# │                                                                                                                 │
# │  ### 1. The TCS Digital Edge - What to Expect in Hiring                                                         │
# │                                                                                                                 │
# │  *   **Online Assessment:** Typically includes advanced aptitude, reasoning, and two to three challenging       │
# │  coding questions (often with higher difficulty than TCS Ninja).                                                │
# │  *   **Technical Interview (TI):** Focuses heavily on Data Structures & Algorithms, programming concepts,       │
# │  project discussions, and core computer science fundamentals.                                                   │
# │  *   **Managerial Interview (MI):** May assess your problem-solving approach, teamwork, leadership potential,   │
# │  and ability to handle complex scenarios.                                                                       │
# │  *   **HR Interview (HRI):** Covers communication skills, career aspirations, fit for company culture, and      │
# │  background verification.                                                                                       │
# │                                                                                                                 │
# │  ### 2. Your Tech Toolkit - Essential Skills                                                                    │
# │                                                                                                                 │
# │  *   **Core Programming Languages:** Strong proficiency in at least one language like Java, Python, C++, or C#  │
# │  is essential.                                                                                                  │
# │  *   **Data Structures & Algorithms (DSA):** In-depth understanding and implementation skills for various DSA   │
# │  are critical for coding rounds and technical interviews.                                                       │
# │  *   **Databases:** Solid knowledge of SQL (queries, normalization, ACID properties) and a basic understanding  │
# │  of NoSQL databases.                                                                                            │
# │  *   **Cloud Computing Fundamentals:** Familiarity with concepts of cloud platforms (AWS, Azure, GCP) and       │
# │  services is highly valued.                                                                                     │
# │  *   **Emerging Technologies:** Basic understanding of AI/ML, IoT, Blockchain, or Big Data concepts can be a    │
# │  differentiator.                                                                                                │
# │                                                                                                                 │
# │  ### 3. Are You Eligible? - Key Criteria                                                                        │
# │                                                                                                                 │
# │  *   **Academic Scores:** Consistent academic performance, generally 60% or 6.0 CGPA throughout 10th, 12th,     │
# │  and B.Tech/BE.                                                                                                 │
# │  *   **Degree and Branches:** B.Tech/BE in Computer Science, Information Technology, Electronics &              │
# │  Communication, Electrical & Electronics, and related disciplines.                                              │
# │  *   **Year of Passing:** Typically targeted towards final-year students (e.g., 2024 batch) or recent           │
# │  graduates within a specific window.                                                                            │
# │  *   **Backlogs:** No active backlogs allowed at the time of application or joining; candidates must have       │
# │  cleared all subjects.                                                                                          │
# │  *   **Education Gap:** A maximum of 1-2 years gap in education is usually permissible, with valid              │
# │  justification.                                                                                                 │
# │                                                                                                                 │
# │  ### 4. Navigating Trends - What's New in Hiring                                                                │
# │                                                                                                                 │
# │  *   **Increased Coding Difficulty:** The coding section in the online assessment often includes medium to      │
# │  hard-level problems requiring optimal solutions.                                                               │
# │  *   **Focus on Problem-Solving:** Greater emphasis on a candidate's approach to problem-solving rather than    │
# │  just memorized solutions.                                                                                      │
# │  *   **Cloud & Emerging Tech Relevance:** Growing preference for candidates demonstrating foundational          │
# │  knowledge or projects related to cloud computing or other emerging technologies.                               │
# │  *   **Adaptive Testing:** Online assessments sometimes utilize adaptive testing, where question difficulty     │
# │  adjusts based on previous answers.                                                                             │
# │  *   **Full-Stack/Specialized Skills:** Demand for candidates with either full-stack development skills or      │
# │  deep expertise in a specific area like AI/ML engineering.                                                      │
# │                                                                                                                 │
# │  ### 5. Your Prep Roadmap - Actionable Tips                                                                     │
# │                                                                                                                 │
# │  *   **Master DSA:** Practice Data Structures and Algorithms extensively on platforms like LeetCode,            │
# │  HackerRank, or GeeksforGeeks, focusing on all difficulty levels.                                               │
# │  *   **Strong Language Fundamentals:** Build a solid foundation in your chosen programming language, including  │
# │  OOP concepts, multi-threading, and error handling.                                                             │
# │  *   **Build Projects:** Develop 2-3 significant projects, preferably using relevant technologies (e.g., web    │
# │  development, ML, cloud services), and be prepared to discuss them in detail.                                   │
# │  *   **Core CS Subjects:** Revise fundamentals of Operating Systems, Database Management Systems, and Computer  │
# │  Networks.                                                                                                      │
# │  *   **Mock Interviews:** Participate in mock technical and HR interviews to refine your communication skills   │
# │  and ability to articulate solutions and experiences clearly.                                                   │
# │                                                                                                                 │
# │  Success in TCS Digital demands strategic preparation and a strong technical foundation.                        │
# │  Start early, practice diligently, and showcase your passion for technology.                                    │
# │  Your future in cutting-edge innovation awaits!                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === FINAL OUTPUT ===
#
# # TCS Digital — Placement Prep Brief
#
# Ready to accelerate your career with a premium role at TCS?
# TCS Digital offers B.Tech graduates an opportunity to work on cutting-edge technologies and innovative projects.
# This brief outlines everything you need to know to secure your spot.
#
# ### 1. The TCS Digital Edge - What to Expect in Hiring
#
# *   **Online Assessment:** Typically includes advanced aptitude, reasoning, and two to three challenging coding questions (often with higher difficulty than TCS Ninja).
# *   **Technical Interview (TI):** Focuses heavily on Data Structures & Algorithms, programming concepts, project discussions, and core computer science fundamentals.
# *   **Managerial Interview (MI):** May assess your problem-solving approach, teamwork, leadership potential, and ability to handle complex scenarios.
# *   **HR Interview (HRI):** Covers communication skills, career aspirations, fit for company culture, and background verification.
#
# ### 2. Your Tech Toolkit - Essential Skills
#
# *   **Core Programming Languages:** Strong proficiency in at least one language like Java, Python, C++, or C# is essential.
# *   **Data Structures & Algorithms (DSA):** In-depth understanding and implementation skills for various DSA are critical for coding rounds and technical interviews.
# *   **Databases:** Solid knowledge of SQL (queries, normalization, ACID properties) and a basic understanding of NoSQL databases.
# *   **Cloud Computing Fundamentals:** Familiarity with concepts of cloud platforms (AWS, Azure, GCP) and services is highly valued.
# *   **Emerging Technologies:** Basic understanding of AI/ML, IoT, Blockchain, or Big Data concepts can be a differentiator.
#
# ### 3. Are You Eligible? - Key Criteria
#
# *   **Academic Scores:** Consistent academic performance, generally 60% or 6.0 CGPA throughout 10th, 12th, and B.Tech/BE.
# *   **Degree and Branches:** B.Tech/BE in Computer Science, Information Technology, Electronics & Communication, Electrical & Electronics, and related disciplines.
# *   **Year of Passing:** Typically targeted towards final-year students (e.g., 2024 batch) or recent graduates within a specific window.
# *   **Backlogs:** No active backlogs allowed at the time of application or joining; candidates must have cleared all subjects.
# *   **Education Gap:** A maximum of 1-2 years gap in education is usually permissible, with valid justification.
#
# ### 4. Navigating Trends - What's New in Hiring
#
# *   **Increased Coding Difficulty:** The coding section in the online assessment often includes medium to hard-level problems requiring optimal solutions.
# *   **Focus on Problem-Solving:** Greater emphasis on a candidate's approach to problem-solving rather than just memorized solutions.
# *   **Cloud & Emerging Tech Relevance:** Growing preference for candidates demonstrating foundational knowledge or projects related to cloud computing or other emerging technologies.
# *   **Adaptive Testing:** Online assessments sometimes utilize adaptive testing, where question difficulty adjusts based on previous answers.
# *   **Full-Stack/Specialized Skills:** Demand for candidates with either full-stack development skills or deep expertise in a specific area like AI/ML engineering.
#
# ### 5. Your Prep Roadmap - Actionable Tips
#
# *   **Master DSA:** Practice Data Structures and Algorithms extensively on platforms like LeetCode, HackerRank, or GeeksforGeeks, focusing on all difficulty levels.
# *   **Strong Language Fundamentals:** Build a solid foundation in your chosen programming language, including OOP concepts, multi-threading, and error handling.
# *   **Build Projects:** Develop 2-3 significant projects, preferably using relevant technologies (e.g., web development, ML, cloud services), and be prepared to discuss them in detail.
# *   **Core CS Subjects:** Revise fundamentals of Operating Systems, Database Management Systems, and Computer Networks.
# *   **Mock Interviews:** Participate in mock technical and HR interviews to refine your communication skills and ability to articulate solutions and experiences clearly.
#
# Success in TCS Digital demands strategic preparation and a strong technical foundation.
# Start early, practice diligently, and showcase your passion for technology.
# Your future in cutting-edge innovation awaits!
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 84d8a69c-896d-4631-849b-bd1805d3a476                                                                       │
# │  Final Output: # TCS Digital — Placement Prep Brief                                                             │
# │                                                                                                                 │
# │  Ready to accelerate your career with a premium role at TCS?                                                    │
# │  TCS Digital offers B.Tech graduates an opportunity to work on cutting-edge technologies and innovative         │
# │  projects.                                                                                                      │
# │  This brief outlines everything you need to know to secure your spot.                                           │
# │                                                                                                                 │
# │  ### 1. The TCS Digital Edge - What to Expect in Hiring                                                         │
# │                                                                                                                 │
# │  *   **Online Assessment:** Typically includes advanced aptitude, reasoning, and two to three challenging       │
# │  coding questions (often with higher difficulty than TCS Ninja).                                                │
# │  *   **Technical Interview (TI):** Focuses heavily on Data Structures & Algorithms, programming concepts,       │
# │  project discussions, and core computer science fundamentals.                                                   │
# │  *   **Managerial Interview (MI):** May assess your problem-solving approach, teamwork, leadership potential,   │
# │  and ability to handle complex scenarios.                                                                       │
# │  *   **HR Interview (HRI):** Covers communication skills, career aspirations, fit for company culture, and      │
# │  background verification.                                                                                       │
# │                                                                                                                 │
# │  ### 2. Your Tech Toolkit - Essential Skills                                                                    │
# │                                                                                                                 │
# │  *   **Core Programming Languages:** Strong proficiency in at least one language like Java, Python, C++, or C#  │
# │  is essential.                                                                                                  │
# │  *   **Data Structures & Algorithms (DSA):** In-depth understanding and implementation skills for various DSA   │
# │  are critical for coding rounds and technical interviews.                                                       │
# │  *   **Databases:** Solid knowledge of SQL (queries, normalization, ACID properties) and a basic understanding  │
# │  of NoSQL databases.                                                                                            │
# │  *   **Cloud Computing Fundamentals:** Familiarity with concepts of cloud platforms (AWS, Azure, GCP) and       │
# │  services is highly valued.                                                                                     │
# │  *   **Emerging Technologies:** Basic understanding of AI/ML, IoT, Blockchain, or Big Data concepts can be a    │
# │  differentiator.                                                                                                │
# │                                                                                                                 │
# │  ### 3. Are You Eligible? - Key Criteria                                                                        │
# │                                                                                                                 │
# │  *   **Academic Scores:** Consistent academic performance, generally 60% or 6.0 CGPA throughout 10th, 12th,     │
# │  and B.Tech/BE.                                                                                                 │
# │  *   **Degree and Branches:** B.Tech/BE in Computer Science, Information Technology, Electronics &              │
# │  Communication, Electrical & Electronics, and related disciplines.                                              │
# │  *   **Year of Passing:** Typically targeted towards final-year students (e.g., 2024 batch) or recent           │
# │  graduates within a specific window.                                                                            │
# │  *   **Backlogs:** No active backlogs allowed at the time of application or joining; candidates must have       │
# │  cleared all subjects.                                                                                          │
# │  *   **Education Gap:** A maximum of 1-2 years gap in education is usually permissible, with valid              │
# │  justification.                                                                                                 │
# │                                                                                                                 │
# │  ### 4. Navigating Trends - What's New in Hiring                                                                │
# │                                                                                                                 │
# │  *   **Increased Coding Difficulty:** The coding section in the online assessment often includes medium to      │
# │  hard-level problems requiring optimal solutions.                                                               │
# │  *   **Focus on Problem-Solving:** Greater emphasis on a candidate's approach to problem-solving rather than    │
# │  just memorized solutions.                                                                                      │
# │  *   **Cloud & Emerging Tech Relevance:** Growing preference for candidates demonstrating foundational          │
# │  knowledge or projects related to cloud computing or other emerging technologies.                               │
# │  *   **Adaptive Testing:** Online assessments sometimes utilize adaptive testing, where question difficulty     │
# │  adjusts based on previous answers.                                                                             │
# │  *   **Full-Stack/Specialized Skills:** Demand for candidates with either full-stack development skills or      │
# │  deep expertise in a specific area like AI/ML engineering.                                                      │
# │                                                                                                                 │
# │  ### 5. Your Prep Roadmap - Actionable Tips                                                                     │
# │                                                                                                                 │
# │  *   **Master DSA:** Practice Data Structures and Algorithms extensively on platforms like LeetCode,            │
# │  HackerRank, or GeeksforGeeks, focusing on all difficulty levels.                                               │
# │  *   **Strong Language Fundamentals:** Build a solid foundation in your chosen programming language, including  │
# │  OOP concepts, multi-threading, and error handling.                                                             │
# │  *   **Build Projects:** Develop 2-3 significant projects, preferably using relevant technologies (e.g., web    │
# │  development, ML, cloud services), and be prepared to discuss them in detail.                                   │
# │  *   **Core CS Subjects:** Revise fundamentals of Operating Systems, Database Management Systems, and Computer  │
# │  Networks.                                                                                                      │
# │  *   **Mock Interviews:** Participate in mock technical and HR interviews to refine your communication skills   │
# │  and ability to articulate solutions and experiences clearly.                                                   │
# │                                                                                                                 │
# │  Success in TCS Digital demands strategic preparation and a strong technical foundation.                        │
# │  Start early, practice diligently, and showcase your passion for technology.                                    │
# │  Your future in cutting-edge innovation awaits!                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
import pathlib

pathlib.Path("day10_lab10a_transcript.txt").write_text(str(result))

print("Saved: day10_lab10a_transcript.txt")
print("Characters:", len(str(result)))
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Saved: day10_lab10a_transcript.txt
# Characters: 4265
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
try:
    for i, output in enumerate(result.tasks_output):
        print(f"\n=== Task {i+1} Output ===")
        print(str(output)[:800])
except Exception:
    print("Task outputs not available in this CrewAI version.")
    print("Final result saved successfully.")
# Out:
# === Task 1 Output ===
# **TCS Digital Placement Preparation for B.Tech Students**
#
# ### Hiring Process
# *   **Online Assessment:** Typically includes advanced aptitude, reasoning, and two to three coding questions (often with higher difficulty than TCS Ninja).
# *   **Technical Interview (TI):** Focuses heavily on Data Structures & Algorithms, programming concepts, project discussions, and core computer science fundamentals.
# *   **Managerial Interview (MI):** May assess problem-solving approach, teamwork, leadership potential, and ability to handle complex scenarios.
# *   **HR Interview (HRI):** Covers communication skills, career aspirations, fit for company culture, and background verification.
#
# ### Technical Stack
# *   **Core Programming Languages:** Strong proficiency in at least one language like Java, Python, C++
#
# === Task 2 Output ===
# # TCS Digital — Placement Prep Brief
#
# Ready to accelerate your career with a premium role at TCS?
# TCS Digital offers B.Tech graduates an opportunity to work on cutting-edge technologies and innovative projects.
# This brief outlines everything you need to know to secure your spot.
#
# ### 1. The TCS Digital Edge - What to Expect in Hiring
#
# *   **Online Assessment:** Typically includes advanced aptitude, reasoning, and two to three challenging coding questions (often with higher difficulty than TCS Ninja).
# *   **Technical Interview (TI):** Focuses heavily on Data Structures & Algorithms, programming concepts, project discussions, and core computer science fundamentals.
# *   **Managerial Interview (MI):** May assess your problem-solving approach, teamwork, leadership potential, and ability to hand

# %%
markdown_content = str(result)

with open("tcs_digital_brief.md", "w", encoding="utf-8") as f:
    f.write(markdown_content)

print("Markdown file created successfully: tcs_digital_brief.md")
# Out:
# Markdown file created successfully: tcs_digital_brief.md

# %%
from google.colab import files

files.download("tcs_digital_brief.md")

# %%
with open("tcs_digital_brief.md", "r", encoding="utf-8") as f:
    print(f.read()[:2000])
# Out:
# # TCS Digital — Placement Prep Brief
#
# Ready to accelerate your career with a premium role at TCS?
# TCS Digital offers B.Tech graduates an opportunity to work on cutting-edge technologies and innovative projects.
# This brief outlines everything you need to know to secure your spot.
#
# ### 1. The TCS Digital Edge - What to Expect in Hiring
#
# *   **Online Assessment:** Typically includes advanced aptitude, reasoning, and two to three challenging coding questions (often with higher difficulty than TCS Ninja).
# *   **Technical Interview (TI):** Focuses heavily on Data Structures & Algorithms, programming concepts, project discussions, and core computer science fundamentals.
# *   **Managerial Interview (MI):** May assess your problem-solving approach, teamwork, leadership potential, and ability to handle complex scenarios.
# *   **HR Interview (HRI):** Covers communication skills, career aspirations, fit for company culture, and background verification.
#
# ### 2. Your Tech Toolkit - Essential Skills
#
# *   **Core Programming Languages:** Strong proficiency in at least one language like Java, Python, C++, or C# is essential.
# *   **Data Structures & Algorithms (DSA):** In-depth understanding and implementation skills for various DSA are critical for coding rounds and technical interviews.
# *   **Databases:** Solid knowledge of SQL (queries, normalization, ACID properties) and a basic understanding of NoSQL databases.
# *   **Cloud Computing Fundamentals:** Familiarity with concepts of cloud platforms (AWS, Azure, GCP) and services is highly valued.
# *   **Emerging Technologies:** Basic understanding of AI/ML, IoT, Blockchain, or Big Data concepts can be a differentiator.
#
# ### 3. Are You Eligible? - Key Criteria
#
# *   **Academic Scores:** Consistent academic performance, generally 60% or 6.0 CGPA throughout 10th, 12th, and B.Tech/BE.
# *   **Degree and Branches:** B.Tech/BE in Computer Science, Information Technology, Electronics & Communication, Electrical & Electronics, and related discipline

# %%
# !pip install -q "numpy<2.0"

# %%
# !pip install -q --upgrade crewai litellm google-generativeai google-genai chromadb sentence-transformers crewai-tools

# %%
import os, getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("Enter Gemini API Key: ")

print("API key set")
# Out:
# Enter Gemini API Key: ··········
# API key set

# %%
from crewai import Agent, Task, Crew, Process
from crewai.tools import tool as crewai_tool

from chromadb import PersistentClient
from sentence_transformers import SentenceTransformer

import json
import pathlib

# %%
llm = "gemini/gemini-2.5-flash"

print(llm)
# Out:
# gemini/gemini-2.5-flash

# %%
client_db = PersistentClient(path='./chroma_db')

col = client_db.get_or_create_collection('placement_kb')

embed = SentenceTransformer(
    'sentence-transformers/all-MiniLM-L6-v2'
)

@crewai_tool
def rag_search(query: str) -> str:
    """
    Search placement knowledge base.
    """

    qv = embed.encode([query]).tolist()

    results = col.query(
        query_embeddings=qv,
        n_results=4
    )

    docs = results['documents'][0]

    return '\n---\n'.join(docs)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
researcher = Agent(
    role="Placement Researcher",

    goal="Research company placement requirements for students",

    backstory="You prepare factual placement research notes using RAG search.",

    llm=llm,

    tools=[rag_search],

    verbose=True,

    allow_delegation=False,
)

# %%
interviewer = Agent(
    role="Mock Interviewer",

    goal="Generate placement interview questions",

    backstory="You generate technical and HR interview questions.",

    llm=llm,

    verbose=True,

    allow_delegation=False,
)

# %%
coach = Agent(
    role="Answer Coach",

    goal="Create strong sample answers and preparation guidance",

    backstory="You coach students with strong placement answers.",

    llm=llm,

    verbose=True,

    allow_delegation=False,
)

# %%
tracker = Agent(
    role="Progress Tracker",

    goal="Create structured student progress summaries",

    backstory="You generate JSON-style student progress summaries.",

    llm=llm,

    verbose=True,

    allow_delegation=False,
)

# %%
profiles = [
    {
        "student_id": "S001",
        "name": "Ravi Kumar",
        "branch": "CSE",
        "cgpa": 7.8,
        "skills": ["Python", "Java", "SQL"],
        "target_company": "TCS Digital"
    },

    {
        "student_id": "S002",
        "name": "Sneha Reddy",
        "branch": "ECE",
        "cgpa": 8.1,
        "skills": ["Python", "DBMS"],
        "target_company": "Cognizant"
    },

    {
        "student_id": "S003",
        "name": "Arun Pillai",
        "branch": "IT",
        "cgpa": 8.5,
        "skills": ["Java", "DSA", "OOPs"],
        "target_company": "Amazon"
    }
]

# %%
def build_tasks(profile):

    research = Task(
        description=(
            f"Research placement preparation details for "
            f"{profile['target_company']} "
            f"for a {profile['branch']} student."
        ),

        agent=researcher,

        expected_output="Short bullet research notes."
    )

    interview = Task(
        description=(
            f"Generate EXACTLY 10 mock interview questions "
            f"for {profile['name']} targeting "
            f"{profile['target_company']}."
        ),

        agent=interviewer,

        expected_output="Exactly 10 numbered interview questions."
    )

    coaching = Task(
        description=(
            f"Pick question 3 and create strong sample answer "
            f"for {profile['name']}."
        ),

        agent=coach,

        expected_output="One strong answer and 3 preparation tips."
    )

    tracking = Task(
        description=(
            f"Create JSON-style progress summary "
            f"for {profile['student_id']}."
        ),

        agent=tracker,

        expected_output="Valid JSON-style summary."
    )

    return [research, interview, coaching, tracking]

# %%
p = profiles[0]

crew = Crew(
    agents=[
        researcher,
        interviewer,
        coach,
        tracker
    ],

    tasks=build_tasks(p),

    process=Process.sequential,

    verbose=True,
)

# %%
result = await crew.kickoff_async()

print("\n=== FINAL OUTPUT ===\n")

print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 7247b756-3a75-4acc-9264-7b39e16fbd24                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research placement preparation details for TCS Digital for a CSE student.                                │
# │  ID: a10126f5-c52f-4905-a2bc-5c141aec636d                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research placement preparation details for TCS Digital for a CSE student.                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 503 - This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.
# An unknown error occurred. Please check the details below.
# Error details: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ERROR:crewai.flow.flow:Error executing listener call_llm_native_tools: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 503 - This model is currently experiencing high demand. Spikes in demand are   │
# │  usually temporary. Please try again later.                                                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# An unknown error occurred. Please check the details below.
# Error details: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research placement preparation details for TCS Digital for a CSE student.                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 503 - This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.
# An unknown error occurred. Please check the details below.
# Error details: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ERROR:crewai.flow.flow:Error executing listener call_llm_native_tools: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 503 - This model is currently experiencing high demand. Spikes in demand are   │
# │  usually temporary. Please try again later.                                                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# An unknown error occurred. Please check the details below.
# Error details: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research placement preparation details for TCS Digital for a CSE student.                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────── 🔧 Tool Execution Started (#1) ─────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool: rag_search                                                                                               │
# │  Args: {'query': 'TCS Digital placement preparation for CSE student'}                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Tool rag_search executed with result: ...
# ╭─────────────────────────────────────── ✅ Tool Execution Completed (#1) ────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool Completed                                                                                                 │
# │  Tool: rag_search                                                                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────── 🔧 Tool Execution Started (#2) ─────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool: rag_search                                                                                               │
# │  Args: {'query': 'TCS Digital placement preparation'}                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Tool rag_search executed with result: ...
# ╭─────────────────────────────────────── ✅ Tool Execution Completed (#2) ────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool Completed                                                                                                 │
# │  Tool: rag_search                                                                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────── 🔧 Tool Execution Started (#3) ─────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool: rag_search                                                                                               │
# │  Args: {'query': 'TCS placement preparation'}                                                                   │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Tool rag_search executed with result: ...
# ╭─────────────────────────────────────── ✅ Tool Execution Completed (#3) ────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool Completed                                                                                                 │
# │  Tool: rag_search                                                                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  I apologize, but I couldn't find any relevant information regarding placement preparation details for TCS      │
# │  Digital for a CSE student in my knowledge base.                                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research placement preparation details for TCS Digital for a CSE student.                                │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Generate EXACTLY 10 mock interview questions for Ravi Kumar targeting TCS Digital.                       │
# │  ID: 6794db21-17ff-4a43-aca4-f69b579954bb                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Mock Interviewer                                                                                        │
# │                                                                                                                 │
# │  Task: Generate EXACTLY 10 mock interview questions for Ravi Kumar targeting TCS Digital.                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Generate EXACTLY 10 mock interview questions for Ravi Kumar targeting TCS Digital.                       │
# │  Agent: Mock Interviewer                                                                                        │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Mock Interviewer                                                                                        │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here are 10 mock interview questions for Ravi Kumar targeting TCS Digital:                                     │
# │                                                                                                                 │
# │  1.  Ravi, please introduce yourself and walk us through your academic background, highlighting any specific    │
# │  areas or projects you're passionate about.                                                                     │
# │  2.  Tell us about a significant technical project you've worked on, either as part of your curriculum or       │
# │  independently. What was your role, what technologies did you use, and what challenges did you overcome?        │
# │  3.  Explain the concept of Object-Oriented Programming (OOP) and its four core principles with a practical     │
# │  example for each.                                                                                              │
# │  4.  Describe the difference between SQL and NoSQL databases. In what scenarios would you prefer one over the   │
# │  other, especially in a "Digital" context with large data volumes?                                              │
# │  5.  Walk us through the different types of data structures you are familiar with. When would you use a hash    │
# │  map over a balanced binary search tree, and what are their respective time complexities for common             │
# │  operations?                                                                                                    │
# │  6.  In the context of web development, explain the difference between front-end and back-end development. If   │
# │  you were to design a scalable web application for a digital service, what architectural pattern would you      │
# │  consider, and why?                                                                                             │
# │  7.  TCS Digital often involves working with emerging technologies like Cloud, AI/ML, or IoT. Are you familiar  │
# │  with any of these areas, and if so, can you discuss a concept or tool you find particularly interesting?       │
# │  8.  What excites you about a career in TCS Digital? How do you envision your skills and aspirations aligning   │
# │  with the kind of work we do in the digital transformation space?                                               │
# │  9.  Describe a situation where you faced a complex technical problem. How did you approach breaking it down,   │
# │  finding a solution, and what was the outcome?                                                                  │
# │  10. Where do you see yourself professionally in the next five years, and what steps are you taking today to    │
# │  achieve those goals?                                                                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Pick question 3 and create strong sample answer for Ravi Kumar.                                          │
# │  ID: 203954d1-cbb0-4dfa-b08e-ce8ec0410c49                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Answer Coach                                                                                            │
# │                                                                                                                 │
# │  Task: Pick question 3 and create strong sample answer for Ravi Kumar.                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash
# Please retry in 25.799763381s.
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 25.799763381s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '25s'}]}}
# ERROR:crewai.flow.flow:Error executing listener call_llm_and_parse: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 25.799763381s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '25s'}]}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing      │
# │  details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To    │
# │  monitor your current usage, head to: https://ai.dev/rate-limit.                                                │
# │  * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5,  │
# │  model: gemini-2.5-flash                                                                                        │
# │  Please retry in 25.799763381s.                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 25.799763381s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '25s'}]}}
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Answer Coach                                                                                            │
# │                                                                                                                 │
# │  Task: Pick question 3 and create strong sample answer for Ravi Kumar.                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash
# Please retry in 25.51271087s.
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 25.51271087s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '25s'}]}}
# ERROR:crewai.flow.flow:Error executing listener call_llm_and_parse: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 25.51271087s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '25s'}]}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing      │
# │  details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To    │
# │  monitor your current usage, head to: https://ai.dev/rate-limit.                                                │
# │  * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5,  │
# │  model: gemini-2.5-flash                                                                                        │
# │  Please retry in 25.51271087s.                                                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 25.51271087s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '25s'}]}}
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Answer Coach                                                                                            │
# │                                                                                                                 │
# │  Task: Pick question 3 and create strong sample answer for Ravi Kumar.                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash
# Please retry in 25.232019553s.
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 25.232019553s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '25s'}]}}
# ERROR:crewai.flow.flow:Error executing listener call_llm_and_parse: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 25.232019553s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '25s'}]}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing      │
# │  details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To    │
# │  monitor your current usage, head to: https://ai.dev/rate-limit.                                                │
# │  * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5,  │
# │  model: gemini-2.5-flash                                                                                        │
# │  Please retry in 25.232019553s.                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 25.232019553s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '25s'}]}}
# [CrewAIEventsBus] Warning: Event pairing mismatch. 'task_failed' closed 'agent_execution_started' (expected
# 'task_started')
# [CrewAIEventsBus] Warning: Event pairing mismatch. 'crew_kickoff_failed' closed 'agent_execution_started' (expected
# 'crew_kickoff_started')
# ╭──────────────────────────────────────────────── 📋 Task Failure ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Failed                                                                                                    │
# │  Name: Pick question 3 and create strong sample answer for Ravi Kumar.                                          │
# │  Agent: Answer Coach                                                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────────── Crew Failure ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Failed                                                                                          │
# │  Name: crew                                                                                                     │
# │  ID: 7247b756-3a75-4acc-9264-7b39e16fbd24                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_11500/3171575050.py in <cell line: 1>()
# ----> 1 result = await crew.kickoff_async()
#       2
#       3 print("\n=== FINAL OUTPUT ===\n")
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/agent_builder/base_agent.py in kickoff_async(self, inputs, input_files, from_checkpoint)
#    1134
# -> 1135         return await asyncio.to_thread(self.kickoff, inputs, input_files)
#    1136
#
# ...
#     737         self._check_execution_error(e, task)
# --> 738         return self.execute_task(task, context, tools)
#     739
#     740     async def _handle_execution_error_async(
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/agent_builder/base_agent.py in execute_task(self, task, context, tools)
#     826             raise e
#     827         except Exception as e:
# --> 828             result = self._handle_execution_error(e, task, context, tools)
#     829
#     830         return self._finalize_task_execution(task, result)
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/agent_builder/base_agent.py in _handle_execution_error(self, e, task, context, tools)
#     736         """
#     737         self._check_execution_error(e, task)
# --> 738         return self.execute_task(task, context, tools)
#     739
#     740     async def _handle_execution_error_async(
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/agent_builder/base_agent.py in execute_task(self, task, context, tools)
#     826             raise e
#     827         except Exception as e:
# --> 828             result = self._handle_execution_error(e, task, context, tools)
#     829
#     830         return self._finalize_task_execution(task, result)
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/agent_builder/base_agent.py in _handle_execution_error(self, e, task, context, tools)
#     735             Result from retried execution.
#     736         """
# --> 737         self._check_execution_error(e, task)
#     738         return self.execute_task(task, context, tools)
#     739
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/agent_builder/base_agent.py in _check_execution_error(self, e, task)
#     715                 ),
#     716             )
# --> 717             raise e
#     718
#     719     def _handle_execution_error(
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/agent_builder/base_agent.py in execute_task(self, task, context, tools)
#     813                 )
#     814             else:
# --> 815                 result = self._execute_without_timeout(task_prompt, task)
#     816
#     817         except TimeoutError as e:
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/agent_builder/base_agent.py in _execute_without_timeout(self, task_prompt, task)
#     878             raise RuntimeError("Agent executor is not initialized.")
#     879
# --> 880         invoke_result = self.agent_executor.invoke(
#     881             {
#     882                 "input": task_prompt,
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/agent_builder/base_agent.py in invoke(self, inputs)
#    2673
#    2674             with _llm_stop_words_applied(self.llm, self):
# -> 2675                 self.kickoff()
#    2676
#    2677                 formatted_answer = self.state.current_answer
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/agent_builder/base_agent.py in kickoff(self, inputs, input_files, from_checkpoint, restore_from_state_id)
#    2135                 return pool.submit(ctx.run, asyncio.run, _run_flow()).result()
#    2136         except RuntimeError:
# -> 2137             return asyncio.run(_run_flow())
#    2138
#    2139     async def kickoff_async(
#
# /usr/lib/python3.12/asyncio/runners.py in run(main, debug, loop_factory)
#     193
#     194     with Runner(debug=debug, loop_factory=loop_factory) as runner:
# --> 195         return runner.run(main)
#     196
#     197
#
# /usr/lib/python3.12/asyncio/runners.py in run(self, coro, context)
#     116         self._interrupt_count = 0
#     117         try:
# --> 118             return self._loop.run_until_complete(task)
#     119         except exceptions.CancelledError:
#     120             if self._interrupt_count > 0:
#
# /usr/lib/python3.12/asyncio/base_events.py in run_until_complete(self, future)
#     689             raise RuntimeError('Event loop stopped before Future completed.')
#     690
# --> 691         return future.result()
#     692
#     693     def stop(self):
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/agent_builder/base_agent.py in _run_flow()
#    2123
#    2124         async def _run_flow() -> Any:
# -> 2125             return await self.kickoff_async(
#    2126                 inputs,
#    2127                 input_files,
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/agent_builder/base_agent.py in kickoff_async(self, inputs, input_files, from_checkpoint, restore_from_state_id)
#    2373                     for start_method in starts_to_execute
#    2374                 ]
# -> 2375                 await asyncio.gather(*tasks)
#    2376             except Exception as e:
#    2377                 # Check if flow was paused for human feedback
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/agent_builder/base_agent.py in _execute_start_method(self, start_method_name)
#    2594             )
#    2595         else:
# -> 2596             await self._execute_listeners(start_method_name, result, finished_event_id)
#    2597
#    2598     def _inject_trigger_payload_for_start_method(
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/agent_builder/base_agent.py in _execute_listeners(self, trigger_method, result, triggering_event_id)
#    2820                     router_result,
#    2821                     current_triggering_event_id,
# -> 2822                 ) = await self._execute_single_listener(
#    2823                     router_name, router_input, current_triggering_event_id
#    2824                 )
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/agent_builder/base_agent.py in _execute_single_listener(self, listener_name, result, triggering_event_id)
#    3147                     )
#    3148
# -> 3149             await self._execute_listeners(
#    3150                 listener_name, listener_result, finished_event_id
#    3151             )
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/agent_builder/base_agent.py in _execute_listeners(self, trigger_method, result, triggering_event_id)
#    2820                     router_result,
#    2821                     current_triggering_event_id,
# -> 2822                 ) = await self._execute_single_listener(
#    2823                     router_name, router_input, current_triggering_event_id
#    2824                 )
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/agent_builder/base_agent.py in _execute_single_listener(self, listener_name, result, triggering_event_id)
#    3143                     )
#    3144                 else:
# -> 3145                     listener_result, finished_event_id = await self._execute_method(
#    3146                         listener_name, method
#    3147                     )
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/agent_builder/base_agent.py in _execute_method(self, method_name, method, *args, **kwargs)
#    2760                 if future:
#    2761                     self._event_futures.append(future)
# -> 2762             raise e
#    2763
#    2764     def _copy_and_serialize_state(self) -> dict[str, Any]:
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/agent_builder/base_agent.py in _execute_method(self, method_name, method, *args, **kwargs)
#    2678                     # This allows Agent.kickoff() to work synchronously inside Flow methods
#    2679                     ctx = contextvars.copy_context()
# -> 2680                     result = await asyncio.to_thread(ctx.run, method, *args, **kwargs)
#    2681             finally:
#    2682                 current_flow_method_name.reset(method_name_token)
#
# /usr/lib/python3.12/asyncio/threads.py in to_thread(func, *args, **kwargs)
#      23     ctx = contextvars.copy_context()
#      24     func_call = functools.partial(ctx.run, func, *args, **kwargs)
# ---> 25     return await loop.run_in_executor(None, func_call)
#
# /usr/lib/python3.12/concurrent/futures/thread.py in run(self)
#      57
#      58         try:
# ---> 59             result = self.fn(*self.args, **self.kwargs)
#      60         except BaseException as exc:
#      61             self.future.set_exception(exc)
#
# /usr/local/lib/python3.12/dist-packages/crewai/flow/flow_wrappers.py in __call__(self, *args, **kwargs)
#      92         """
#      93         if self._instance is not None:
# ---> 94             return self._meth(self._instance, *args, **kwargs)
#      95         return self._meth(*args, **kwargs)
#      96
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/agent_builder/base_agent.py in call_llm_and_parse(self)
#    1278             )
#    1279
# -> 1280             answer = get_llm_response(
#    1281                 llm=self.llm,
#    1282                 messages=list(self.state.messages),
#
# /usr/local/lib/python3.12/dist-packages/crewai/utilities/agent_utils.py in get_llm_response(llm, messages, callbacks, printer, tools, available_functions, from_task, from_agent, response_model, executor_context, verbose)
#     488     messages = _prepare_llm_call(executor_context, messages, printer, verbose=verbose)
#     489
# --> 490     answer = llm.call(
#     491         messages,
#     492         tools=tools,
#
# /usr/local/lib/python3.12/dist-packages/crewai/llms/providers/gemini/completion.py in call(self, messages, tools, callbacks, available_functions, from_task, from_agent, response_model)
#     333                     )
#     334
# --> 335                 return self._handle_completion(
#     336                     formatted_content,
#     337                     config,
#
# /usr/local/lib/python3.12/dist-packages/crewai/llms/providers/gemini/completion.py in _handle_completion(self, contents, config, available_functions, from_task, from_agent, response_model)
#    1122                 logging.error(f"Context window exceeded: {e}")
#    1123                 raise LLMContextLengthExceededError(str(e)) from e
# -> 1124             raise e from e
#    1125
#    1126         self._track_token_usage_internal(usage)
#
# /usr/local/lib/python3.12/dist-packages/crewai/llms/providers/gemini/completion.py in _handle_completion(self, contents, config, available_functions, from_task, from_agent, response_model)
#    1111             # The API accepts list[Content] but mypy is overly strict about variance
#    1112             contents_for_api: Any = contents
# -> 1113             response = self._get_sync_client().models.generate_content(
#    1114                 model=self.model,
#    1115                 contents=contents_for_api,
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    6452     while remaining_remote_calls_afc > 0:
#    6453       i += 1
# -> 6454       response = self._generate_content(
#    6455           model=model, contents=contents, config=parsed_config
#    6456       )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4888     request_dict = _common.encode_unserializable_types(request_dict)
#    4889
# -> 4890     response = self._api_client.request(
#    4891         'post', path, request_dict, http_options
#    4892     )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in request(self, http_method, path, request_dict, http_options)
#    1609         http_method, path, request_dict, http_options
#    1610     )
# -> 1611     response = self._request(http_request, http_options, stream=False)
#    1612     response_body = (
#    1613         response.response_stream[0] if response.response_stream else ''
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request(self, http_request, http_options, stream)
#    1402         return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1403
# -> 1404     return self._retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1405
#    1406   async def _async_request_once(
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     468         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469         while True:
# --> 470             do = self.iter(retry_state=retry_state)
#     471             if isinstance(do, DoAttempt):
#     472                 try:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     369         result = None
#     370         for action in self.iter_state.actions:
# --> 371             result = action(retry_state)
#     372         return result
#     373
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in exc_check(rs)
#     411                 retry_exc = self.retry_error_cls(fut)
#     412                 if self.reraise:
# --> 413                     raise retry_exc.reraise()
#     414                 raise retry_exc from fut.exception()
#     415
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in reraise(self)
#     182     def reraise(self) -> t.NoReturn:
#     183         if self.last_attempt.failed:
# --> 184             raise self.last_attempt.result()
#     185         raise self
#     186
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     471             if isinstance(do, DoAttempt):
#     472                 try:
# --> 473                     result = fn(*args, **kwargs)
#     474                 except BaseException:  # noqa: B902
#     475                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request_once(self, http_request, stream)
#    1379       )
#    1380       response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1381     errors.APIError.raise_for_response(response)
#    1382     return HttpResponse(
#    1383         response.headers, response if stream else [response.text]
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_for_response(cls, response)
#     153       response_json = response.body_segments[0].get('error', {})
#     154
# --> 155     cls.raise_error(response.status_code, response_json, response)
#     156
#     157   @classmethod
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_error(cls, status_code, response_json, response)
#     182     """
#     183     if 400 <= status_code < 500:
# --> 184       raise ClientError(status_code, response_json, response)
#     185     elif 500 <= status_code < 600:
#     186       raise ServerError(status_code, response_json, response)
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 25.232019553s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '25s'}]}}
