# %% [markdown]
# <a href="https://colab.research.google.com/github/BOBBYKIRAN/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid describes the essential skill sets needed to build and deploy AI systems, from foundational data to user experience:
#
# *   **Data Layer:** The base, focusing on acquiring, cleaning, and labeling the raw data essential for AI.
# *   **Model Layer:** Building, training, and evaluating the machine learning models using the prepared data.
# *   **Deployment Layer:** Operationalizing the models, integrating them into systems, and managing their performance in production.
# *   **Business Logic & UX Layers:** Defining the AI's purpose, how it fits into business processes, and designing its interaction with end-users.
